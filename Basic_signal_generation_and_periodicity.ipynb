# %% [markdown]
# a) Write a python program to generate the following signals, for all the cases take information about $f$ and $T_{s}$ from the user. Observe the signal variation by keeping the $T_{s}$ constant and varying the frequency $f$.
#
# 1.   x(n)=cos(2$\pi f n T_{s}$)
# 2.   x(n)=rectangular signal of amplitude variation from -1 to 1 and 0 to 1.
#
# 3. x(n)= triangular signal. Take  $\%$ of rising edge information also from the user.
# 4. x(n)= $e^{-n T_{s}}$ cos(2 $\pi f_{n}T_{s}$)
#
# b) Plot the signals cos($ \frac{\pi n}{3}$) and $cos(\frac{n}{3})$ and show the periodicity information from the plot.
#
# c) From the week 1 problem solving assignment:
#  practice qustion no. 1(a), 2(a), 4(a,b) for programming assignment, and only submit question no.: 4(b)

# %% [markdown]
# Programming Assignment 1:
#
# ***Signal generation and periodicity***
#
# Course Instructor: S.R.M. Prasanna

# %%
import numpy as np

import matplotlib.pyplot as plt

# example code for a(1)
f=1

fs=50

n=np.linspace(-5,5,10*fs)

x=np.sin(2*(np.pi)*f*n)

plt.plot(n,x)
